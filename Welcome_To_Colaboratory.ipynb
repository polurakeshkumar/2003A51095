# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('/content/drive/MyDrive/forestfires.csv')

# %%
x=d['DMC']
y=d['FFMC']
plt.plot(x,y,'r','b')

# %%
x=d['DC']
y=d['FFMC']
plt.plot(x,y,'r','b')

# %%
x=d['ISI']
y=d['FFMC']
plt.plot(x,y,'r','b')

# %%
x=d['temp']
y=d['FFMC']
plt.plot(x,y,'r','b')

# %%
x=d['RH']
y=d['FFMC']
plt.plot(x,y,'r','b')

# %%
x=d['wind']
y=d['FFMC']
plt.plot(x,y,'r','b')

# %%
x=d['rain']
y=d['FFMC']
plt.plot(x,y,'r','b')

# %%
x=d['area']
y=d['FFMC']
plt.plot(x,y,'r','b')
