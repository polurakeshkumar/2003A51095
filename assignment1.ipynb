# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('/content/drive/MyDrive/pokemon_alopez247.csv')

# %%
x=d['HP']
y=d['isLegendary']
plt.plot(x,y,'r','b')

# %%
x=d['Attack']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Defense']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Sp_Atk']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Sp_Def']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Speed']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Generation']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['hasGender']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Pr_Male']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['hasMegaEvolution']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Height_m']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Weight_kg']
y=d['isLegendary']
plt.plot(x,y,'r')

# %%
x=d['Catch_Rate']
y=d['isLegendary']
plt.plot(x,y,'r')
